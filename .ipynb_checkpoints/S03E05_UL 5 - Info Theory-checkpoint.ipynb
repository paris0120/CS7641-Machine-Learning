# %% [markdown]
# 1. Mutual information: are these input vectors similar? How different they are?
# 1. Entropy: does this feature have any information?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. if the sequence is predictable or has less uncertainty, it has less information
# 1. Entropy: if you have to predict the next symbol in a sequence, what is the minimum number of yes or no you would expect to ask
#     1. case one information: 1 ask every question
#     1. case two information: 0 ask no question

# %% [markdown]
# ### Message carry information
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Entropy
# 1. #(s): size = log 1/p(s)
# 1. Entropy formular
#     1.  $ H(S) = -\sum P(S) * log P(S) $

# %% [markdown]
# ### Information between two variables
# 1. joint entropy
#     1. $H(X,Y) = -\sum P(X,Y) log P(X,Y)$
# 1. Conditional entropy
#     1. $H(Y|X) = -\sum P(X,Y) log P(Y|X)$
#     1. not good dependency measures
#         1. if small
#             1. if x tells us a great deal about y or
#             1. x or y is very small to begin with
# 1. If X||y
#     1. H(Y|X) = H(Y)
#     1. H(X,Y) = H(X) + H(Y)

# %% [markdown]
# ### Mutual Information
# 1. dependency measures
# 1. I(X,Y) = H(Y) - H(X|Y)
# 1. notes?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Kullback-Leibler (KL) Divergence
# 1. $D(p||q) = \int p(x)log {p(x) \over q(x)}$
# 1. measure the difference between two distributions
# 1. always
#     1. non-negative
#     1. 0 only when P == Q
# 1. useful
#     1. try to model data to a particular distribution
#     1. if one of our distributions can be of unkown distribution
#     1. we can denote that as P(X)
#     1. as a subtitude to the least square for fitting
#     1. different way of fit your data to existing model

# %% [markdown]
# ### Summary
# 1. Information
# 1. Entropy
# 1. Joint Entropy
# 1. Conditional Entropy
# 1. Mutual Information
# 1. KL Divergence
